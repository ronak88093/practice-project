# %% [markdown]
# # IMPORTING LIBS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # LOADING DATA

# %%
data=pd.read_csv('insurance.csv')
data
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %% [markdown]
# **here 4 num columns and 3 object columns**

# %%
data.isnull().sum() # no null value
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
data.isna().sum() # no missing value
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %% [markdown]
# # Converting Categorical Features to Numerical

# %%
data['sex']=data['sex'].map({'male':1,'female':0})
data['smoker']=data['smoker'].map({'yes':1,'no':0})
data['region']=data['region'].map({'southwest':0,'southeast':1,'northwest':2,'northeast':3})
data
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    0  27.900         0       1       0  16884.92400
# 1      18    1  33.770         1       0       1   1725.55230
# 2      28    1  33.000         3       0       1   4449.46200
# 3      33    1  22.705         0       0       2  21984.47061
# 4      32    1  28.880         0       0       2   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    1  30.970         3       0       2  10600.54830
# 1334   18    0  31.920         0       0       3   2205.98080
# 1335   18    0  36.850         0       0       1   1629.83350
# 1336   21    0  25.800         0       0       0   2007.94500
# 1337   61    0  29.070         0       1       2  29141.36030
#
# [1338 rows x 7 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   int64
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   int64
#  5   region    1338 non-null   int64
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(5)
# memory usage: 73.3 KB

# %% [markdown]
# **now all values are numerical**

# %%
data.describe()
# Out:
#                age          sex          bmi     children       smoker  \
# count  1338.000000  1338.000000  1338.000000  1338.000000  1338.000000
# mean     39.207025     0.505232    30.663397     1.094918     0.204783
# std      14.049960     0.500160     6.098187     1.205493     0.403694
# min      18.000000     0.000000    15.960000     0.000000     0.000000
# 25%      27.000000     0.000000    26.296250     0.000000     0.000000
# 50%      39.000000     1.000000    30.400000     1.000000     0.000000
# 75%      51.000000     1.000000    34.693750     2.000000     0.000000
# max      64.000000     1.000000    53.130000     5.000000     1.000000
#
#             region       charges
# count  1338.000000   1338.000000
# mean      1.484305  13270.422265
# std       1.104885  12110.011237
# min       0.000000   1121.873900
# 25%       1.000000   4740.287150
# 50%       1.000000   9382.033000
# 75%       2.000000  16639.912515
# max       3.000000  63770.428010

# %% [markdown]
# This shows a brief description of the Charges column.<br>
# Few observations:-
# * The minimum cost of an insurance is 1122
# * Around 75% of the charges are below 16,700
# * The maximum cost of an insurance is 63770

# %% [markdown]
# # EDA

# %%
plt.figure(figsize=(9,6))
plt.title('Age vs Charge')
sns.barplot(x='age',y='charges',data=data,palette='husl')
plt.show()

# %% [markdown]
# **its show that when age increse charges going up**

# %%
plt.figure(figsize=(7,5))
plt.title('Region vs Charge')
sns.barplot(x='region',y='charges',data=data,palette='Set3')
plt.show()

# %% [markdown]
# **its show region is not much effective on charges**

# %%
plt.figure(figsize=(7,5))
sns.scatterplot(x='bmi',y='charges',hue='sex',data=data,palette='Reds')
plt.title('BMI VS Charge')
plt.show()

# %% [markdown]
# **bmi is not effective on charges**

# %%
plt.figure(figsize=(7,5))
plt.title('Smoker vs Charge')
sns.barplot(x='smoker',y='charges',data=data,palette='Blues',hue='sex')
# Out:
# <AxesSubplot:title={'center':'Smoker vs Charge'}, xlabel='smoker', ylabel='charges'>

# %% [markdown]
# **smoking is so much effective on charges**

# %%
plt.figure(figsize=(7,5))
plt.title('Sex vs Charges')
sns.barplot(x='sex',y='charges',data=data,palette='Set1')
plt.show()

# %% [markdown]
# **plot show that female is less charges then male**

# %%
plt.figure(figsize=(7,5))
plt.title('Sex vs Charges')
sns.barplot(x='children',y='charges',data=data,palette='Set1')
plt.show()

# %% [markdown]
# **children is not much effect on insurence cost**

# %% [markdown]
# Few observations:-<br>
# * Smoking and age has the highest impact on the medical insurance costs.
# * children, region has not much effect on cost.
# * bmi,sex has less effective on cost.

# %%
plt.figure(figsize=(10,7))
sns.heatmap(data.corr(),linewidths=0.1,fmt=".2g",annot=True)
plt.yticks(rotation=0);
plt.show()

# %% [markdown]
# **no correlation except mostaly smoking and then age**

# %% [markdown]
# # visulization graph of correlation between target and feature

# %%
plt.figure(figsize=(22,7))
data.corr()['charges'].sort_values(ascending=False).drop(['charges']).plot(kind='bar',color='g')
plt.xlabel('feature',fontsize=15)
plt.ylabel('Target',fontsize=15)
plt.show()

# %% [markdown]
# **none of the feature is negetive for taget**

# %% [markdown]
# # DATA PREDICTION

# %%
x=data.drop(['charges'],axis=1) # independent variable
y=data['charges']               # dependent variable

# %%
x
# Out:
#       age  sex     bmi  children  smoker  region
# 0      19    0  27.900         0       1       0
# 1      18    1  33.770         1       0       1
# 2      28    1  33.000         3       0       1
# 3      33    1  22.705         0       0       2
# 4      32    1  28.880         0       0       2
# ...   ...  ...     ...       ...     ...     ...
# 1333   50    1  30.970         3       0       2
# 1334   18    0  31.920         0       0       3
# 1335   18    0  36.850         0       0       1
# 1336   21    0  25.800         0       0       0
# 1337   61    0  29.070         0       1       2
#
# [1338 rows x 6 columns]

# %%
y
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %%
# dividing the dataset in training and testing set
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=0)

# %%
x.shape,y.shape
# Out:
# ((1338, 6), (1338,))

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((1003, 6), (335, 6), (1003,), (335,))

# %%
# importing model
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# %% [markdown]
# **TRAINING THE MODEL**

# %%
lr= LinearRegression()
lr.fit(x_train, y_train)

rf=RandomForestRegressor()
rf.fit(x_train, y_train)

gb=GradientBoostingRegressor()
gb.fit(x_train, y_train)


dtr=DecisionTreeRegressor()
dtr.fit(x_train, y_train)

svr=SVR()
svr.fit(x_train, y_train)
# Out:
# SVR()

# %% [markdown]
# **CLACULATE ACCURACY**

# %%
acc=lr.score(x_test,y_test)
print("accuracy score of LR is = ",acc*100,"%")
acc=rf.score(x_test,y_test)
print("accuracy score RF is = ",acc*100,"%")
acc=gb.score(x_test,y_test)
print("accuracy score GB is = ",acc*100,"%")
acc=dtr.score(x_test,y_test)
print("accuracy score DTR is = ",acc*100,"%")
acc=svr.score(x_test,y_test)
print("accuracy score SVR is = ",acc*100,"%")
# Out:
# accuracy score of LR is =  79.62732059725785 %
# accuracy score RF is =  87.20057593121192 %
# accuracy score GB is =  89.77408077267833 %
# accuracy score DTR is =  66.05422178959101 %
# accuracy score SVR is =  -9.774782783388837 %

# %% [markdown]
# **BEST MODEL FOR TESTING IS Gradient Boosting Regressor**

# %% [markdown]
# # hyper perameter tuning for GradientBoostingRegressor

# %%
param_grid = {
    'n_estimators': [50, 100, 200],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [3, 4, 5],
    'min_samples_split': [2, 3, 4],
    'min_samples_leaf': [1, 2, 3]
}

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid1 = GridSearchCV(estimator=gb, param_grid=param_grid, cv=5, scoring='accuracy')

# %%
grid1.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=GradientBoostingRegressor(),
#              param_grid={'learning_rate': [0.01, 0.1, 0.2],
#                          'max_depth': [3, 4, 5], 'min_samples_leaf': [1, 2, 3],
#                          'min_samples_split': [2, 3, 4],
#                          'n_estimators': [50, 100, 200]},
#              scoring='accuracy')

# %%
best_params = grid1.best_params_
best_params
# Out:
# {'learning_rate': 0.01,
#  'max_depth': 3,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 50}

# %%
best_regressor = grid1.best_estimator_
best_regressor
# Out:
# GradientBoostingRegressor(learning_rate=0.01, n_estimators=50)

# %%
final_gb = GradientBoostingRegressor(learning_rate=0.01, n_estimators=50)

final_gb.fit(x_train,y_train)
predgb=final_gb.predict(x_test)
acc=gb.score(x_test,y_test)
print("accuracy score GB is = ",acc*100,"%")
# Out:
# accuracy score GB is =  89.77408077267833 %

# %% [markdown]
# # SAVING THE MODEL

# %%
gb=GradientBoostingRegressor() # model trained for whole data
gb.fit(x, y)
# Out:
# GradientBoostingRegressor()

# %%
import joblib
joblib.dump(gb,'MEDICAL INSURANCE COST.pk1')
# Out:
# ['MEDICAL INSURANCE COST.pk1']

# %% [markdown]
# **PREDICTION MODEL**

# %%
# new user prediction example-1
df=pd.DataFrame({'age':54,'sex':0, 'bmi':40.3, 'children':2, 'smoker':1, 'region':3},index=[0])
df
# Out:
#    age  sex   bmi  children  smoker  region
# 0   54    0  40.3         2       1       3

# %%
model=joblib.load('MEDICAL INSURANCE COST.pk1')
prediction=model.predict(df)

prediction                     # prediction as per user input a data
# Out:
# array([48961.33105419])

# %%
# new user prediction example-2
# just change a smoker to non smoker
df1=pd.DataFrame({'age':54,'sex':0, 'bmi':40.3, 'children':2, 'smoker':0, 'region':3},index=[0])
model=joblib.load('MEDICAL INSURANCE COST.pk1')
prediction=model.predict(df1)
prediction
# Out:
# array([14669.91759269])

# %% [markdown]
# **predicted cost of non smoker is 75% less then smoker cost**

# %% [markdown]
# # conclusion

# %% [markdown]
# * **Smoking** is the greatest factor that affects medical cost charges, then it's **bmi** and **age**.
# * **Gradient Boosting Regressor** turned out to be the best model.
